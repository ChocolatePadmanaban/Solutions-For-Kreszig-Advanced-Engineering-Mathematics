# %% [markdown]
# # Data Representation

# %% [markdown]
# ### Represent the following data in stem-and-leaf plot, a histogram and a boxplot
#
#
# 1. Length of  nails [mm]
#
#       20 21 20 19 21 19

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
#1  19 21 19 20 19 20 21 20  lenght of nails 
a_1 = np.array([20, 21, 20, 19, 21, 19])
n,bins , patches = plt.hist(a_1, bins=3)
plt.xlabel('Length of Nails')
plt.ylabel('No of people')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Length of Nails'])
boxplot = df.boxplot(column=['Length of Nails'])

# %% [markdown]
#  2. Phone calls perminute in an office between 9:00 A.M and 9:10 A.M

# %%
#2    6 6 4 2 1 7 0 4 6 7 calls every minute 
#minute view 
calls_every_min = [6,6,4,2,1,7,0,4,6,7]
plt.bar([_ for _ in range(len(calls_every_min))], calls_every_min, color='g')
plt.show()

# %%
df = pd.DataFrame(calls_every_min, columns=['Calls every minute'])
boxplot = df.boxplot(column=['Calls every minute'])

# %%
#frequency view  calls ever minute 
a_1 = np.array([6, 6, 4, 2, 1, 7, 0, 4, 6, 7])
n,bins , patches = plt.hist(a_1)
plt.xlabel('Calls per minute')
plt.ylabel('calls')
plt.grid(True)
plt.show()

# %% [markdown]
#  3. Systolic blood pressure of 15 female patiens of ages 20-22

# %%
#3 Systolic blood pressure of 15 female patients of ages 20–22
a_1 = np.array([156,158,154,133,141,130,144,137,151,146,156,138,138,149,139])
n,bins , patches = plt.hist(a_1,bins=[130,135,140,145,150,155,160])
plt.xlabel('Blood pressure')
plt.ylabel('number of female patients')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Blood Pressure'])
boxplot = df.boxplot(column=['Blood Pressure'])

# %% [markdown]
#  4. Iron content [%] of 15 specimens of hermatite (Fe<sub>2</sub>O<sub>3</sub>)

# %%
#4 Iron content [%] of 15 specimens of hermatite (Fe 2 O 3 )
a_1 = np.array([72.8,71.5,70.4,69.7,71.2,70.5,69.2,71.3,70.3,69.1,68.9,70.9,71.1,70.6,69.8])
n,bins , patches = plt.hist(a_1,bins=[69,69.5,70,70.5,71,71.5,72,72.5,73])
plt.xlabel('Iron content %')
plt.ylabel('number of speciments of hermatite')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Iron Content'])
boxplot = df.boxplot(column=['Iron Content'])

# %% [markdown]
#  5. Weeight of filled bags [g] in an automatic filling

# %%
#5 Weight of filled bags [g] in an automatic filling
a_1 = np.array([203,199,198,201,200,201,201])
n,bins , patches = plt.hist(a_1)
plt.xlabel('Weight of bags')
plt.ylabel('number of bags')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Weight of bags'])
boxplot = df.boxplot(column=['Weight of bags'])

# %% [markdown]
# 6. Gasoline consumption [miles per gallon, rounded] of six cars of the same model under similar conditions

# %%
#6 Gasoline consumption [miles per gallon, rounded] of six cars of the same model under similar conditions
a_1=np.array([15.0,15.5,14.5,15.0,15.5,15.0])
n,bins , patches = plt.hist(a_1)
plt.xlabel('Gasoline consumption')
plt.ylabel('no of cars')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Gasoline Consumption'])
boxplot = df.boxplot(column=['Gasoline Consumption'])

# %% [markdown]
#  7. Release time [sec] of a relay

# %%
#7 Release time [sec] of a relay
a_1= np.array([1.3,1.2,1.4,1.5,1.3,1.3,1.4,1.1,1.5,1.4,1.6,1.3,1.5,1.1,1.4,1.2,1.3,1.5,1.4,1.4])
n,bins , patches = plt.hist(a_1,bins=[1.1,1.2,1.3,1.4,1.5,1.6])
plt.xlabel('Release time of relay')
plt.ylabel('no of relays')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Release time of relay'])
boxplot = df.boxplot(column=['Release time of relay'])

# %% [markdown]
# 8 . Foundrax test of Brinell hardness (2.5 mm steel ball, 62.5 kg load, 30 sec) of 20 copper plates (values in kg/mm<sup>2</sup> )

# %%
#8 Foundrax test of Brinell hardness (2.5 mm steel ball,
# 62.5 kg load, 30 sec) of 20 copper plates (values in
# kg>mm 2 )
a_1 = np.array([86,90,86,88,87,89,89,90,76,88,85,80,82,84,86,89,87,90,85,89])
n,bins , patches = plt.hist(a_1,bins=[76,80,84,88,92])
plt.xlabel('brinell hardness')
plt.ylabel('no of stell balls')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Brinell Hardness'])
boxplot = df.boxplot(column=['Brinell Hardness'])

# %% [markdown]
# 9. Efficiency [%] of seven Voith Francis turbines of runner diameter 2.3 m under a head range of 185 m

# %%
# 9. Efficiency [%] of seven Voith Francis turbines of
# runner diameter 2.3 m under a head range of 185 m
a_1=np.array([91.8,89.1,89.9,92.5,90.7,91.2,91.0])
n,bins , patches = plt.hist(a_1,bins=[89,90,91,92,93])
plt.xlabel('effecienty')
plt.ylabel('no of turbines')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1,columns=['Efficiency'])
boxplot = df.boxplot(column=['Efficiency'])

# %% [markdown]
#  10 . -0.51, 0.12, -0.47, 0.95, 0.25, -0.18, -0.54

# %%
#10
a_1=np.array([-0.51, 0.12, -0.47, 0.95, 0.25, -0.18, -0.54])
n,bins , patches = plt.hist(a_1)
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(a_1)
boxplot = df.boxplot()

# %% [markdown]
# ## Find the mean and compare it with the median. Find the standard deviation and compare it with the interquartile range.

# %%
#11 19 21 19 20 19 20 21 20  lenght of nails 
a_1 = np.array([20, 21, 20, 19, 21, 19])
print("Mean of the array ", a_1,"is ", np.mean(a_1))
print("Median of the array", a_1, "is", np.median(a_1))
print("standard deviation of the array", a_1, "is", np.std(a_1))
print("Interquatile range of the array", a_1, "is", stats.iqr(a_1, interpolation='midpoint'))
# Out:
# Mean of the array  [20 21 20 19 21 19] is  20.0
# Median of the array [20 21 20 19 21 19] is 20.0
# standard deviation of the array [20 21 20 19 21 19] is 0.816496580927726
# Interquatile range of the array [20 21 20 19 21 19] is 1.0

# %%
calls_every_min = [6,6,4,2,1,7,0,4,6,7]
print("Mean of the array ", calls_every_min,"is ", np.mean(calls_every_min))
print("Median of the array", calls_every_min, "is", np.median(calls_every_min))
print("standard deviation of the array", calls_every_min, "is", np.std(calls_every_min))
print("Interquatile range of the array", calls_every_min, "is", stats.iqr(calls_every_min, interpolation='midpoint'))
# Out:
# Mean of the array  [6, 6, 4, 2, 1, 7, 0, 4, 6, 7] is  4.3
# Median of the array [6, 6, 4, 2, 1, 7, 0, 4, 6, 7] is 5.0
# standard deviation of the array [6, 6, 4, 2, 1, 7, 0, 4, 6, 7] is 2.4103941586387903
# Interquatile range of the array [6, 6, 4, 2, 1, 7, 0, 4, 6, 7] is 3.0

# %%
a_1 = np.array([156,158,154,133,141,130,144,137,151,146,156,138,138,149,139])
print("Mean of the array ", a_1,"is ", np.mean(a_1))
print("Median of the array", a_1, "is", np.median(a_1))
print("standard deviation of the array", a_1, "is", np.std(a_1))
print("Interquatile range of the array", a_1, "is", stats.iqr(a_1, interpolation='midpoint'))
# Out:
# Mean of the array  [156 158 154 133 141 130 144 137 151 146 156 138 138 149 139] is  144.66666666666666
# Median of the array [156 158 154 133 141 130 144 137 151 146 156 138 138 149 139] is 144.0
# standard deviation of the array [156 158 154 133 141 130 144 137 151 146 156 138 138 149 139] is 8.669230390037836
# Interquatile range of the array [156 158 154 133 141 130 144 137 151 146 156 138 138 149 139] is 14.5

# %%
a_1 = np.array([72.8,71.5,70.4,69.7,71.2,70.5,69.2,71.3,70.3,69.1,68.9,70.9,71.1,70.6,69.8])
print("Mean of the array ", a_1,"is ", np.mean(a_1))
print("Median of the array", a_1, "is", np.median(a_1))
print("standard deviation of the array", a_1, "is", np.std(a_1))
print("Interquatile range of the array", a_1, "is", stats.iqr(a_1, interpolation='midpoint'))
# Out:
# Mean of the array  [72.8 71.5 70.4 69.7 71.2 70.5 69.2 71.3 70.3 69.1 68.9 70.9 71.1 70.6
#  69.8] is  70.48666666666666
# Median of the array [72.8 71.5 70.4 69.7 71.2 70.5 69.2 71.3 70.3 69.1 68.9 70.9 71.1 70.6
#  69.8] is 70.5
# standard deviation of the array [72.8 71.5 70.4 69.7 71.2 70.5 69.2 71.3 70.3 69.1 68.9 70.9 71.1 70.6
#  69.8] is 1.0111819267020585
# Interquatile range of the array [72.8 71.5 70.4 69.7 71.2 70.5 69.2 71.3 70.3 69.1 68.9 70.9 71.1 70.6
#  69.8] is 1.4000000000000057

# %%
a_1= np.array([1.3,1.2,1.4,1.5,1.3,1.3,1.4,1.1,1.5,1.4,1.6,1.3,1.5,1.1,1.4,1.2,1.3,1.5,1.4,1.4])
print("Mean of the array ", a_1,"is ", np.mean(a_1))
print("Median of the array", a_1, "is", np.median(a_1))
print("standard deviation of the array", a_1, "is", np.std(a_1))
print("Interquatile range of the array", a_1, "is", stats.iqr(a_1, interpolation='midpoint'))
# Out:
# Mean of the array  [1.3 1.2 1.4 1.5 1.3 1.3 1.4 1.1 1.5 1.4 1.6 1.3 1.5 1.1 1.4 1.2 1.3 1.5
#  1.4 1.4] is  1.355
# Median of the array [1.3 1.2 1.4 1.5 1.3 1.3 1.4 1.1 1.5 1.4 1.6 1.3 1.5 1.1 1.4 1.2 1.3 1.5
#  1.4 1.4] is 1.4
# standard deviation of the array [1.3 1.2 1.4 1.5 1.3 1.3 1.4 1.1 1.5 1.4 1.6 1.3 1.5 1.1 1.4 1.2 1.3 1.5
#  1.4 1.4] is 0.13219304066402285
# Interquatile range of the array [1.3 1.2 1.4 1.5 1.3 1.3 1.4 1.1 1.5 1.4 1.6 1.3 1.5 1.1 1.4 1.2 1.3 1.5
#  1.4 1.4] is 0.1499999999999999

# %%
a_1 = np.array([86,90,86,88,87,89,89,90,76,88,85,80,82,84,86,89,87,90,85,89])
print("Mean of the array ", a_1,"is ", np.mean(a_1))
print("Median of the array", a_1, "is", np.median(a_1))
print("standard deviation of the array", a_1, "is", np.std(a_1))
print("Interquatile range of the array", a_1, "is", stats.iqr(a_1, interpolation='midpoint'))
# Out:
# Mean of the array  [86 90 86 88 87 89 89 90 76 88 85 80 82 84 86 89 87 90 85 89] is  86.3
# Median of the array [86 90 86 88 87 89 89 90 76 88 85 80 82 84 86 89 87 90 85 89] is 87.0
# standard deviation of the array [86 90 86 88 87 89 89 90 76 88 85 80 82 84 86 89 87 90 85 89] is 3.536947836765479
# Interquatile range of the array [86 90 86 88 87 89 89 90 76 88 85 80 82 84 86 89 87 90 85 89] is 4.0
