# %%
# %matplotlib inline

# %%
#1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- np.pi,np.pi,400)
y = np.exp(x)

y = np.array(y)
plt.plot(x,y,'-')

# %%
#1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 10,10,400)
y = []
for i in x:
    if i < 0:
        y.append(np.exp(i))
    else:
        y.append(np.exp(-i))

y = np.array(y)
plt.plot(x,y,'-')

# %%
#1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 50,50,4000)
y = []
for i in x:
    y.append((i**3)*np.cos(2*i))

y = np.array(y)
plt.plot(x,y,'-')

# %%
#1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 10,10,400)
y = []
for i in x:
    y.append((i**2)*np.tan(np.pi*i))

y = np.array(y)
plt.plot(x,y,'-')

# %%
#1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 10,10,400)
y = []
for i in x:
    y.append(np.sinh(i)-np.cos(i))

y = np.array(y)
plt.plot(x,y,'-')

# %%
#2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 10,10,400)
y = []
for i in x:
    y.append(np.sin(i)**2)

y = np.array(y)
plt.plot(x,y,'-')

# %%
#2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 5,5,400)
y = []
for i in x:
    y.append(np.sin(i**2))

y = np.array(y)
plt.plot(x,y,'-')

# %%
#2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 5,5,400)
y = []
for i in x:
    y.append(np.log(i))

y = np.array(y)
plt.plot(x,y,'-')
# Out:
# /home/janani/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log

# %%
#2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 5,5,400)
y = []
for i in x:
    y.append(i/(1+i**2))

y = np.array(y)
plt.plot(x,y,'-')

# %%
#2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 5,5,400)
y = []
for i in x:
    y.append(i/np.tan(i))

y = np.array(y)
plt.plot(x,y,'-')

# %% [markdown]
#    #3.
#    Even Functions is f(x) where f(-x)= f(x).
#
#    So sum of even functions:
#
#    g(-x)+ f(-x) = g(x)+f(x) .
#
#    if both g(x) and f(x) are even function then their sum is also even
#
#    So product of even functions:
#
#    g(-x)* f(-x) = g(x)*f(x) .
#
#    if both g(x) and f(x) are even function then their product is also even

# %% [markdown]
# #4. odd Functions is f(x) where f(-x)= -f(x)
#
#    So sum of odd functions:
#
#    g(-x)+ f(-x) = -g(x)-f(x)
#
#    if both g(x) and f(x) are even function then their sum is also odd
#
#    So product of odd functions:
#
#    g(-x)* f(-x) = g(x)*f(x)
#
#    if both g(x) and f(x) are even function then their product is even

# %% [markdown]
# 6.let g(x) be odd function so g(-x) = -g(x)
# let f(x) be even function so f(-x) = f(x)
# do odd times even f(x).g(x)
# f(-x).g(-x)= - f(x).g(x)
# so the product is also odd

# %%
#8 its a even funtion 

from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols("x")

def even(k,l):
    a0 = integrate(x,(x,0,l))/l
    expr = a0
    stra = 'a1:'+str(k)
    syma = symbols(stra)
    j=1
    for i in syma:
        i = 2*integrate(x*cos(j*pi*x/l), (x,0,l))/l
        expr += i*cos(j*pi*x/l)
        j+=1
    return expr

plt.show(plot(even(40,1),(x,-2,2)))

# %%
even(20,1)
# Out:
#   4⋅cos(π⋅x)   4⋅cos(3⋅π⋅x)   4⋅cos(5⋅π⋅x)   4⋅cos(7⋅π⋅x)   4⋅cos(9⋅π⋅x)   4⋅c
# - ────────── - ──────────── - ──────────── - ──────────── - ──────────── - ───
#        2              2              2              2              2
#       π            9⋅π           25⋅π           49⋅π           81⋅π
#
# os(11⋅π⋅x)   4⋅cos(13⋅π⋅x)   4⋅cos(15⋅π⋅x)   4⋅cos(17⋅π⋅x)   4⋅cos(19⋅π⋅x)   1
# ────────── - ───────────── - ───────────── - ───────────── - ───────────── + ─
#       2               2               2               2               2      2
#  121⋅π           169⋅π           225⋅π           289⋅π           361⋅π

# %%
#9 its a even function
x = symbols("x")

def odd(k,l):
    expr =0
    strb = 'b1:'+str(k)
    symb = symbols(strb)
    j=1
    for i in symb:
        i = 2*integrate(sin(j*pi*x/l), (x,0,l))/l
        expr += i*sin(j*pi*x/l)
        j+=1
    return expr

plt.show(plot(odd(40,2),(x,-4,4)))

# %%
odd(40,2)
# Out:
#      ⎛π⋅x⎞        ⎛3⋅π⋅x⎞        ⎛5⋅π⋅x⎞        ⎛7⋅π⋅x⎞        ⎛9⋅π⋅x⎞
# 4⋅sin⎜───⎟   4⋅sin⎜─────⎟   4⋅sin⎜─────⎟   4⋅sin⎜─────⎟   4⋅sin⎜─────⎟   4⋅sin
#      ⎝ 2 ⎠        ⎝  2  ⎠        ⎝  2  ⎠        ⎝  2  ⎠        ⎝  2  ⎠
# ────────── + ──────────── + ──────────── + ──────────── + ──────────── + ─────
#     π            3⋅π            5⋅π            7⋅π            9⋅π
#
# ⎛11⋅π⋅x⎞        ⎛13⋅π⋅x⎞        ⎛15⋅π⋅x⎞        ⎛17⋅π⋅x⎞        ⎛19⋅π⋅x⎞
# ⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅s
# ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠
# ──────── + ───────────── + ───────────── + ───────────── + ───────────── + ───
# 11⋅π            13⋅π            15⋅π            17⋅π            19⋅π
#
#   ⎛21⋅π⋅x⎞        ⎛23⋅π⋅x⎞        ⎛25⋅π⋅x⎞        ⎛27⋅π⋅x⎞        ⎛29⋅π⋅x⎞
# in⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4
#   ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠
# ────────── + ───────────── + ───────────── + ───────────── + ───────────── + ─
#   21⋅π            23⋅π            25⋅π            27⋅π            29⋅π
#
#     ⎛31⋅π⋅x⎞        ⎛33⋅π⋅x⎞        ⎛35⋅π⋅x⎞        ⎛37⋅π⋅x⎞        ⎛39⋅π⋅x⎞
# ⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟   4⋅sin⎜──────⎟
#     ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠        ⎝  2   ⎠
# ──────────── + ───────────── + ───────────── + ───────────── + ─────────────
#     31⋅π            33⋅π            35⋅π            37⋅π            39⋅π

# %%
#10 is odd function

def odd(k,l):
    expr =0
    strb = 'b1:'+str(k)
    symb = symbols(strb)
    j=1
    for i in symb:
        i = 2*integrate((4-x)*sin(j*pi*x/l), (x,0,l))/l
        expr += i*sin(j*pi*x/l)
        j+=1
    return expr

plt.show(plot(odd(40,4),(x,-8,8)))

# %%
odd(40,4)
# Out:
#      ⎛π⋅x⎞        ⎛π⋅x⎞        ⎛3⋅π⋅x⎞                     ⎛5⋅π⋅x⎞        ⎛3⋅π
# 8⋅sin⎜───⎟   4⋅sin⎜───⎟   8⋅sin⎜─────⎟                8⋅sin⎜─────⎟   4⋅sin⎜───
#      ⎝ 4 ⎠        ⎝ 2 ⎠        ⎝  4  ⎠   2⋅sin(π⋅x)        ⎝  4  ⎠        ⎝  2
# ────────── + ────────── + ──────────── + ────────── + ──────────── + ─────────
#     π            π            3⋅π            π            5⋅π            3⋅π
#
# ⋅x⎞        ⎛7⋅π⋅x⎞                     ⎛9⋅π⋅x⎞        ⎛5⋅π⋅x⎞        ⎛11⋅π⋅x⎞
# ──⎟   8⋅sin⎜─────⎟                8⋅sin⎜─────⎟   4⋅sin⎜─────⎟   8⋅sin⎜──────⎟
#   ⎠        ⎝  4  ⎠   sin(2⋅π⋅x)        ⎝  4  ⎠        ⎝  2  ⎠        ⎝  4   ⎠
# ─── + ──────────── + ────────── + ──────────── + ──────────── + ─────────────
#           7⋅π            π            9⋅π            5⋅π             11⋅π
#
#                       ⎛13⋅π⋅x⎞        ⎛7⋅π⋅x⎞        ⎛15⋅π⋅x⎞
#                  8⋅sin⎜──────⎟   4⋅sin⎜─────⎟   8⋅sin⎜──────⎟                8
#   2⋅sin(3⋅π⋅x)        ⎝  4   ⎠        ⎝  2  ⎠        ⎝  4   ⎠   sin(4⋅π⋅x)
# + ──────────── + ───────────── + ──────────── + ───────────── + ────────── + ─
#       3⋅π             13⋅π           7⋅π             15⋅π          2⋅π
#
#     ⎛17⋅π⋅x⎞        ⎛9⋅π⋅x⎞        ⎛19⋅π⋅x⎞                       ⎛21⋅π⋅x⎞
# ⋅sin⎜──────⎟   4⋅sin⎜─────⎟   8⋅sin⎜──────⎟                  8⋅sin⎜──────⎟   4
#     ⎝  4   ⎠        ⎝  2  ⎠        ⎝  4   ⎠   2⋅sin(5⋅π⋅x)        ⎝  4   ⎠
# ──────────── + ──────────── + ───────────── + ──────────── + ───────────── + ─
#     17⋅π           9⋅π             19⋅π           5⋅π             21⋅π
#
#     ⎛11⋅π⋅x⎞        ⎛23⋅π⋅x⎞                     ⎛25⋅π⋅x⎞        ⎛13⋅π⋅x⎞
# ⋅sin⎜──────⎟   8⋅sin⎜──────⎟                8⋅sin⎜──────⎟   4⋅sin⎜──────⎟   8⋅
#     ⎝  2   ⎠        ⎝  4   ⎠   sin(6⋅π⋅x)        ⎝  4   ⎠        ⎝  2   ⎠
# ──────────── + ───────────── + ────────── + ───────────── + ───────────── + ──
#     11⋅π            23⋅π          3⋅π            25⋅π            13⋅π
#
#    ⎛27⋅π⋅x⎞                       ⎛29⋅π⋅x⎞        ⎛15⋅π⋅x⎞        ⎛31⋅π⋅x⎞
# sin⎜──────⎟                  8⋅sin⎜──────⎟   4⋅sin⎜──────⎟   8⋅sin⎜──────⎟
#    ⎝  4   ⎠   2⋅sin(7⋅π⋅x)        ⎝  4   ⎠        ⎝  2   ⎠        ⎝  4   ⎠   s
# ─────────── + ──────────── + ───────────── + ───────────── + ───────────── + ─
#    27⋅π           7⋅π             29⋅π            15⋅π            31⋅π
#
#                  ⎛33⋅π⋅x⎞        ⎛17⋅π⋅x⎞        ⎛35⋅π⋅x⎞
#             8⋅sin⎜──────⎟   4⋅sin⎜──────⎟   8⋅sin⎜──────⎟                  8⋅s
# in(8⋅π⋅x)        ⎝  4   ⎠        ⎝  2   ⎠        ⎝  4   ⎠   2⋅sin(9⋅π⋅x)
# ───────── + ───────────── + ───────────── + ───────────── + ──────────── + ───
#   4⋅π            33⋅π            17⋅π            35⋅π           9⋅π
#
#   ⎛37⋅π⋅x⎞        ⎛19⋅π⋅x⎞        ⎛39⋅π⋅x⎞
# in⎜──────⎟   4⋅sin⎜──────⎟   8⋅sin⎜──────⎟
#   ⎝  4   ⎠        ⎝  2   ⎠        ⎝  4   ⎠
# ────────── + ───────────── + ─────────────
#   37⋅π            19⋅π            39⋅π

# %%
#11 is an even function

def even(k,l):
    a0 = integrate(x*x,(x,0,l))/l
    expr = a0
    stra = 'a1:'+str(k)
    syma = symbols(stra)
    j=1
    for i in syma:
        i = 2*integrate(x*x*cos(j*pi*x/l), (x,0,l))/l
        expr += i*cos(j*pi*x/l)
        j+=1
    return expr

plt.show(plot(even(20,1),(x,-2,2)))

# %%
even(20,1)
# Out:
#   4⋅cos(π⋅x)   cos(2⋅π⋅x)   4⋅cos(3⋅π⋅x)   cos(4⋅π⋅x)   4⋅cos(5⋅π⋅x)   cos(6⋅π
# - ────────── + ────────── - ──────────── + ────────── - ──────────── + ───────
#        2            2              2             2             2             2
#       π            π            9⋅π           4⋅π          25⋅π           9⋅π
#
# ⋅x)   4⋅cos(7⋅π⋅x)   cos(8⋅π⋅x)   4⋅cos(9⋅π⋅x)   cos(10⋅π⋅x)   4⋅cos(11⋅π⋅x)
# ─── - ──────────── + ────────── - ──────────── + ─────────── - ───────────── +
#              2             2             2              2               2
#          49⋅π          16⋅π          81⋅π           25⋅π           121⋅π
#
#  cos(12⋅π⋅x)   4⋅cos(13⋅π⋅x)   cos(14⋅π⋅x)   4⋅cos(15⋅π⋅x)   cos(16⋅π⋅x)   4⋅c
#  ─────────── - ───────────── + ─────────── - ───────────── + ─────────── - ───
#         2               2             2               2             2
#     36⋅π           169⋅π          49⋅π           225⋅π          64⋅π
#
# os(17⋅π⋅x)   cos(18⋅π⋅x)   4⋅cos(19⋅π⋅x)   1
# ────────── + ─────────── - ───────────── + ─
#       2             2               2      3
#  289⋅π          81⋅π           361⋅π

# %%
#12 
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- 2,2,400)
y = []
for i in x:
    y.append(1-i**2/4)    
y = np.array(y)
plt.plot(x,y,'-')

# %%
# so 12 is even function
x = symbols("x")
def even(k,l):
    
    a0 = integrate(1-x**2/4,(x,0,l))/l
    expr = a0
    stra = 'a1:'+str(k)
    syma = symbols(stra)
    j=1
    for i in syma:
        i = 2*integrate((1-x**2/4)*cos(j*pi*x/l), (x,0,l))/l
        expr += i*cos(j*pi*x/l)
        j+=1
    return expr

plt.show(plot(even(20,2),(x,-4,4)))

# %%
even(20,2)
# Out:
#      ⎛π⋅x⎞                   ⎛3⋅π⋅x⎞                     ⎛5⋅π⋅x⎞
# 4⋅cos⎜───⎟              4⋅cos⎜─────⎟                4⋅cos⎜─────⎟
#      ⎝ 2 ⎠   cos(π⋅x)        ⎝  2  ⎠   cos(2⋅π⋅x)        ⎝  2  ⎠   cos(3⋅π⋅x)
# ────────── - ──────── + ──────────── - ────────── + ──────────── - ──────────
#      2           2             2             2             2             2
#     π           π           9⋅π           4⋅π          25⋅π           9⋅π
#
#        ⎛7⋅π⋅x⎞                     ⎛9⋅π⋅x⎞                     ⎛11⋅π⋅x⎞
#   4⋅cos⎜─────⎟                4⋅cos⎜─────⎟                4⋅cos⎜──────⎟
#        ⎝  2  ⎠   cos(4⋅π⋅x)        ⎝  2  ⎠   cos(5⋅π⋅x)        ⎝  2   ⎠   cos(
# + ──────────── - ────────── + ──────────── - ────────── + ───────────── - ────
#          2             2             2             2               2
#      49⋅π          16⋅π          81⋅π          25⋅π           121⋅π         36
#
#               ⎛13⋅π⋅x⎞                     ⎛15⋅π⋅x⎞                     ⎛17⋅π⋅
#          4⋅cos⎜──────⎟                4⋅cos⎜──────⎟                4⋅cos⎜─────
# 6⋅π⋅x)        ⎝  2   ⎠   cos(7⋅π⋅x)        ⎝  2   ⎠   cos(8⋅π⋅x)        ⎝  2
# ────── + ───────────── - ────────── + ───────────── - ────────── + ───────────
#   2               2            2               2            2               2
# ⋅π           169⋅π         49⋅π           225⋅π         64⋅π           289⋅π
#
# x⎞                     ⎛19⋅π⋅x⎞
# ─⎟                4⋅cos⎜──────⎟
#  ⎠   cos(9⋅π⋅x)        ⎝  2   ⎠   2
# ── - ────────── + ───────────── + ─
#            2               2      3
#        81⋅π           361⋅π

# %%
#13 is neither even nor odd


x = symbols("x")
def fourier(k,l):
    a0 = integrate(x,(x,0,l))/(2*l)
    expr = a0
    stra = 'a1:'+str(k)
    syma = symbols(stra)
    strb = 'b1:'+str(k)
    symb = symbols(strb)
    j=1
    for i in syma:
        i = integrate(x*cos(j*pi*x/l), (x,0,l))/l
        expr += i*cos(j*pi*x/l)
        j+=1
    j = 1
    for i in symb:
        i = integrate(x*sin(j*pi*x/l), (x,0,l))/l
        expr += i*sin(j*pi*x/l)
        j+= 1
    return expr

plt.show(plot(fourier(20,.5),(x,-4,4)))

# %%
fourier(20,.5)
# Out:
# 0.5⋅sin(2.0⋅π⋅x)   0.25⋅sin(4.0⋅π⋅x)   0.166666666666667⋅sin(6.0⋅π⋅x)   0.125⋅
# ──────────────── - ───────────────── + ────────────────────────────── - ──────
#        π                   π                         π
#
#
# sin(8.0⋅π⋅x)   0.1⋅sin(10.0⋅π⋅x)   0.0833333333333333⋅sin(12.0⋅π⋅x)   0.071428
# ──────────── + ───────────────── - ──────────────────────────────── + ────────
#   π                    π                          π
#
#
# 5714285714⋅sin(14.0⋅π⋅x)   0.0625⋅sin(16.0⋅π⋅x)   0.0555555555555556⋅sin(18.0⋅
# ──────────────────────── - ──────────────────── + ────────────────────────────
#        π                            π                            π
#
#
# π⋅x)   0.05⋅sin(20.0⋅π⋅x)   0.0454545454545455⋅sin(22.0⋅π⋅x)   0.0416666666666
# ──── - ────────────────── + ──────────────────────────────── - ───────────────
#                π                           π
#
#
# 667⋅sin(24.0⋅π⋅x)   0.0384615384615385⋅sin(26.0⋅π⋅x)   0.0357142857142857⋅sin(
# ───────────────── + ──────────────────────────────── - ───────────────────────
# π                                  π                                  π
#
#
# 28.0⋅π⋅x)   0.0333333333333333⋅sin(30.0⋅π⋅x)   0.03125⋅sin(32.0⋅π⋅x)   0.02941
# ───────── + ──────────────────────────────── - ───────────────────── + ───────
#                            π                             π
#
#
# 17647058824⋅sin(34.0⋅π⋅x)   0.0277777777777778⋅sin(36.0⋅π⋅x)   0.0263157894736
# ───────────────────────── - ──────────────────────────────── + ───────────────
#         π                                  π
#
#
# 842⋅sin(38.0⋅π⋅x)   1.0⋅cos(2.0⋅π⋅x)   0.111111111111111⋅cos(6.0⋅π⋅x)   0.04⋅c
# ───────────────── - ──────────────── - ────────────────────────────── - ──────
# π                           2                         2
#                            π                         π
#
# os(10.0⋅π⋅x)   0.0204081632653061⋅cos(14.0⋅π⋅x)   0.0123456790123457⋅cos(18.0⋅
# ──────────── - ──────────────────────────────── - ────────────────────────────
#    2                           2                                  2
#   π                           π                                  π
#
# π⋅x)   0.00826446280991736⋅cos(22.0⋅π⋅x)   0.00591715976331361⋅cos(26.0⋅π⋅x)
# ──── - ───────────────────────────────── - ───────────────────────────────── -
#                         2                                   2
#                        π                                   π
#
#  0.00444444444444444⋅cos(30.0⋅π⋅x)   0.00346020761245675⋅cos(34.0⋅π⋅x)   0.002
#  ───────────────────────────────── - ───────────────────────────────── - ─────
#                   2                                   2
#                  π                                   π
#
# 77008310249307⋅cos(38.0⋅π⋅x)
# ──────────────────────────── + 0.125
#             2
#            π

# %%
#14 is an even function


x = symbols("x")
def fourier(k,l):
    a0 = integrate(cos(pi*x),(x,0,l))/l
    expr = a0
    stra = 'a1:'+str(k)
    syma = symbols(stra)
    
    j=1
    for i in syma:
        i = 2*integrate(cos(pi*x)*cos(j*pi*x/l), (x,0,l))/l
        expr += i*cos(j*pi*x/l)
        j+=1
    
    return expr

plt.show(plot(fourier(20,.5),(x,-2,2)))

# %%
fourier(20,.5)
# Out:
# 1.33333333333333⋅cos(2.0⋅π⋅x)   0.266666666666667⋅cos(4.0⋅π⋅x)   0.11428571428
# ───────────────────────────── - ────────────────────────────── + ─────────────
#               π                               π
#
# 5714⋅cos(6.0⋅π⋅x)   0.0634920634920635⋅cos(8.0⋅π⋅x)   0.0404040404040404⋅cos(1
# ───────────────── - ─────────────────────────────── + ────────────────────────
#  π                                 π                                 π
#
# 0.0⋅π⋅x)   0.027972027972028⋅cos(12.0⋅π⋅x)   0.0205128205128205⋅cos(14.0⋅π⋅x)
# ──────── - ─────────────────────────────── + ────────────────────────────────
#                           π                                 π
#
#   0.0156862745098039⋅cos(16.0⋅π⋅x)   0.0123839009287926⋅cos(18.0⋅π⋅x)   0.0100
# - ──────────────────────────────── + ──────────────────────────────── - ──────
#                  π                                  π
#
# 250626566416⋅cos(20.0⋅π⋅x)   0.0082815734989648⋅cos(22.0⋅π⋅x)   0.006956521739
# ────────────────────────── + ──────────────────────────────── - ──────────────
#          π                                  π
#
# 13044⋅cos(24.0⋅π⋅x)   0.00592592592592593⋅cos(26.0⋅π⋅x)   0.00510855683269476⋅
# ─────────────────── + ───────────────────────────────── - ────────────────────
#   π                                   π                                   π
#
# cos(28.0⋅π⋅x)   0.00444938820912125⋅cos(30.0⋅π⋅x)   0.00391006842619746⋅cos(32
# ───────────── + ───────────────────────────────── - ──────────────────────────
#                                 π                                   π
#
# .0⋅π⋅x)   0.00346320346320346⋅cos(34.0⋅π⋅x)   0.00308880308880309⋅cos(36.0⋅π⋅x
# ─────── + ───────────────────────────────── - ────────────────────────────────
#                           π                                   π
#
# )   0.00277200277200277⋅cos(38.0⋅π⋅x)   2.0
# ─ + ───────────────────────────────── + ───
#                     π                    π

# %%
#15 is an odd function 

x = symbols("x")
def fourier(k,l):
    #a0 = integrate(cos(pi*x),(x,0,l))/l
    expr = 0
    strb = 'b1:'+str(k)
    symb  = symbols(strb)    
    j=1
    for i in symb:
        i = 2*(integrate(x*sin(j*pi*x/l),(x,0,pi/2))+integrate((pi-x)*sin(j*pi*x/l),(x,pi/2,pi)))/l
        expr += i*sin(j*pi*x/l)
        j+=1
    
    return expr

plt.show(plot(fourier(20,pi),(x,-6,6)))

# %%
fourier(20,pi)
# Out:
# 4⋅sin(x)   4⋅sin(3⋅x)   4⋅sin(5⋅x)   4⋅sin(7⋅x)   4⋅sin(9⋅x)   4⋅sin(11⋅x)   4
# ──────── - ────────── + ────────── - ────────── + ────────── - ─────────── + ─
#    π          9⋅π          25⋅π         49⋅π         81⋅π         121⋅π
#
# ⋅sin(13⋅x)   4⋅sin(15⋅x)   4⋅sin(17⋅x)   4⋅sin(19⋅x)
# ────────── - ─────────── + ─────────── - ───────────
#   169⋅π         225⋅π         289⋅π         361⋅π

# %%
#16 is an odd function 

x = symbols("x")
def fourier(k,l):
    #a0 = integrate(cos(pi*x),(x,0,l))/l
    expr = 0
    strb = 'b1:'+str(k)
    symb  = symbols(strb)    
    j=1
    for i in symb:
        i = 2*integrate((x**2)*sin(j*pi*x/l),(x,0,1))/l
        expr += i*sin(j*pi*x/l)
        j+=1
    
    return expr

plt.show(plot(fourier(20,1),(x,-2,2)))

# %%
fourier(20,1)
# Out:
# ⎛  8    2⎞            sin(2⋅π⋅x)   ⎛    8      2 ⎞              sin(4⋅π⋅x)   ⎛
# ⎜- ── + ─⎟⋅sin(π⋅x) - ────────── + ⎜- ───── + ───⎟⋅sin(3⋅π⋅x) - ────────── + ⎜
# ⎜   3   π⎟                π        ⎜      3   3⋅π⎟                 2⋅π       ⎜
# ⎝  π     ⎠                         ⎝  27⋅π       ⎠                           ⎝
#
#     8       2 ⎞              sin(6⋅π⋅x)   ⎛    8       2 ⎞              sin(8⋅
# - ────── + ───⎟⋅sin(5⋅π⋅x) - ────────── + ⎜- ────── + ───⎟⋅sin(7⋅π⋅x) - ──────
#        3   5⋅π⎟                 3⋅π       ⎜       3   7⋅π⎟                 4⋅π
#   125⋅π       ⎠                           ⎝  343⋅π       ⎠
#
# π⋅x)   ⎛    8       2 ⎞              sin(10⋅π⋅x)   ⎛     8       2  ⎞
# ──── + ⎜- ────── + ───⎟⋅sin(9⋅π⋅x) - ─────────── + ⎜- ─────── + ────⎟⋅sin(11⋅π
#        ⎜       3   9⋅π⎟                  5⋅π       ⎜        3   11⋅π⎟
#        ⎝  729⋅π       ⎠                            ⎝  1331⋅π        ⎠
#
#       sin(12⋅π⋅x)   ⎛     8       2  ⎞               sin(14⋅π⋅x)   ⎛     8
# ⋅x) - ─────────── + ⎜- ─────── + ────⎟⋅sin(13⋅π⋅x) - ─────────── + ⎜- ───────
#           6⋅π       ⎜        3   13⋅π⎟                   7⋅π       ⎜        3
#                     ⎝  2197⋅π        ⎠                             ⎝  3375⋅π
#
#    2  ⎞               sin(16⋅π⋅x)   ⎛     8       2  ⎞               sin(18⋅π⋅
# + ────⎟⋅sin(15⋅π⋅x) - ─────────── + ⎜- ─────── + ────⎟⋅sin(17⋅π⋅x) - ─────────
#   15⋅π⎟                   8⋅π       ⎜        3   17⋅π⎟                   9⋅π
#       ⎠                             ⎝  4913⋅π        ⎠
#
# x)   ⎛     8       2  ⎞
# ── + ⎜- ─────── + ────⎟⋅sin(19⋅π⋅x)
#      ⎜        3   19⋅π⎟
#      ⎝  6859⋅π        ⎠

# %%
#17 is an even function
x = symbols("x")
def fourier(k,l):
    a0 = integrate(1-x,(x,0,l))/l
    expr = a0
    strb = 'b1:'+str(k)
    symb  = symbols(strb)    
    j=1
    for i in symb:
        i = 2*integrate((1-x)*cos(j*pi*x/l),(x,0,1))/l
        expr += i*cos(j*pi*x/l)
        j+=1
    
    return expr

plt.show(plot(fourier(20,1),(x,-2,2)))

# %%
fourier(20,1)
# Out:
# 4⋅cos(π⋅x)   4⋅cos(3⋅π⋅x)   4⋅cos(5⋅π⋅x)   4⋅cos(7⋅π⋅x)   4⋅cos(9⋅π⋅x)   4⋅cos
# ────────── + ──────────── + ──────────── + ──────────── + ──────────── + ─────
#      2              2              2              2              2
#     π            9⋅π           25⋅π           49⋅π           81⋅π            1
#
# (11⋅π⋅x)   4⋅cos(13⋅π⋅x)   4⋅cos(15⋅π⋅x)   4⋅cos(17⋅π⋅x)   4⋅cos(19⋅π⋅x)   1
# ──────── + ───────────── + ───────────── + ───────────── + ───────────── + ─
#     2               2               2               2               2      2
# 21⋅π           169⋅π           225⋅π           289⋅π           361⋅π

# %%
#19 a is neither even nor odd
#21
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = integrate(cos(x)**3,(x,-pi,pi))/(2*pi)
    expr = a0
    #print(float(a0))
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = integrate((cos(x)**3)*cos(j*x),(x,-pi,pi))/pi 
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i = integrate((cos(x)**3)*sin(j*x),(x,-pi,pi))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
#print(expr)
plt.show(plot(expr1(40),(x,-2*pi,2*pi)))
expr1(40)
