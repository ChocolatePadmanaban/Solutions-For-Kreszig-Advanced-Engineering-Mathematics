# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#6
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    if i<0:
        y.append(-i)
    else:
        y.append(i)
y = np.array(y)
plt.plot(x,y,'-')

# %%
#7.a
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    if i<0:
        y.append(-np.sin(i))
    else:
        y.append(np.sin(i))
y = np.array(y)
plt.plot(x,y,'-')

# %%
#7.b
x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    if i<0:
        y.append(np.sin(-i))
    else:
        y.append(np.sin(i))
y = np.array(y)
plt.plot(x,y,'-')

# %%
#8.a
x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    if i<0:
        y.append(np.exp(i))
    else:
        y.append(np.exp(-i))
y = np.array(y)
plt.plot(x,y,'-')

# %%
#8.b
x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    y.append(np.exp(-i))
y = np.array(y)
plt.plot(x,y,'-')

# %%
#9
x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    if i<0:
        y.append(i)
    else:
        y.append(np.pi-i)
y = np.array(y)
plt.plot(x,y,'-')

# %%
#10
x = np.linspace(- np.pi,np.pi,400)
y = []
for i in x:
    if i<0:
        y.append(-(np.cos(i))**2)
    else:
        y.append((np.cos(i))**2)
y = np.array(y)
plt.plot(x,y,'-')

# %%
# 12
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = (integrate(-x,(x,-pi,0))+integrate(x, (x,0,pi)))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = (integrate(-x*cos(j*x),(x,-pi,0))+
            integrate(x*cos(j*x),(x,0,pi)))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i =  (integrate(-x*sin(j*x),(x,-pi,0))+
            integrate(x*sin(j*x),(x,0,pi)))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
#print(expand(expr))
plot(expr1(20),(x,-2*pi,2*pi))

# %%
expr1(20)
# Out:
#   4⋅cos(x)   4⋅cos(3⋅x)   4⋅cos(5⋅x)   4⋅cos(7⋅x)   4⋅cos(9⋅x)   4⋅cos(11⋅x)
# - ──────── - ────────── - ────────── - ────────── - ────────── - ─────────── -
#      π          9⋅π          25⋅π         49⋅π         81⋅π         121⋅π
#
#  4⋅cos(13⋅x)   4⋅cos(15⋅x)   4⋅cos(17⋅x)   4⋅cos(19⋅x)   π
#  ─────────── - ─────────── - ─────────── - ─────────── + ─
#     169⋅π         225⋅π         289⋅π         361⋅π      2

# %%
# 13
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = (integrate(x,(x,-pi,0))+integrate(pi-x, (x,0,pi)))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = (integrate(x*cos(j*x),(x,-pi,0))+
            integrate((pi-x)*cos(j*x),(x,0,pi)))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i =  (integrate(x*sin(j*x),(x,-pi,0))+
            integrate((pi-x)*sin(j*x),(x,0,pi)))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(50),(x,-2*pi,2*pi))

# %%
expr1(50)
# Out:
#            2⋅sin(3⋅x)   2⋅sin(5⋅x)   2⋅sin(7⋅x)   2⋅sin(9⋅x)   2⋅sin(11⋅x)   2
# 2⋅sin(x) + ────────── + ────────── + ────────── + ────────── + ─────────── + ─
#                3            5            7            9             11
#
# ⋅sin(13⋅x)   2⋅sin(15⋅x)   2⋅sin(17⋅x)   2⋅sin(19⋅x)   2⋅sin(21⋅x)   2⋅sin(23⋅
# ────────── + ─────────── + ─────────── + ─────────── + ─────────── + ─────────
#     13            15            17            19            21            23
#
# x)   2⋅sin(25⋅x)   2⋅sin(27⋅x)   2⋅sin(29⋅x)   2⋅sin(31⋅x)   2⋅sin(33⋅x)   2⋅s
# ── + ─────────── + ─────────── + ─────────── + ─────────── + ─────────── + ───
#           25            27            29            31            33
#
# in(35⋅x)   2⋅sin(37⋅x)   2⋅sin(39⋅x)   2⋅sin(41⋅x)   2⋅sin(43⋅x)   2⋅sin(45⋅x)
# ──────── + ─────────── + ─────────── + ─────────── + ─────────── + ───────────
#   35            37            39            41            43            45
#
#    2⋅sin(47⋅x)   2⋅sin(49⋅x)   4⋅cos(x)   4⋅cos(3⋅x)   4⋅cos(5⋅x)   4⋅cos(7⋅x)
#  + ─────────── + ─────────── + ──────── + ────────── + ────────── + ──────────
#         47            49          π          9⋅π          25⋅π         49⋅π
#
#    4⋅cos(9⋅x)   4⋅cos(11⋅x)   4⋅cos(13⋅x)   4⋅cos(15⋅x)   4⋅cos(17⋅x)   4⋅cos(
#  + ────────── + ─────────── + ─────────── + ─────────── + ─────────── + ──────
#       81⋅π         121⋅π         169⋅π         225⋅π         289⋅π         361
#
# 19⋅x)   4⋅cos(21⋅x)   4⋅cos(23⋅x)   4⋅cos(25⋅x)   4⋅cos(27⋅x)   4⋅cos(29⋅x)
# ───── + ─────────── + ─────────── + ─────────── + ─────────── + ─────────── +
# ⋅π         441⋅π         529⋅π         625⋅π         729⋅π         841⋅π
#
# 4⋅cos(31⋅x)   4⋅cos(33⋅x)   4⋅cos(35⋅x)   4⋅cos(37⋅x)   4⋅cos(39⋅x)   4⋅cos(41
# ─────────── + ─────────── + ─────────── + ─────────── + ─────────── + ────────
#    961⋅π         1089⋅π        1225⋅π        1369⋅π        1521⋅π        1681⋅
#
# ⋅x)   4⋅cos(43⋅x)   4⋅cos(45⋅x)   4⋅cos(47⋅x)   4⋅cos(49⋅x)
# ─── + ─────────── + ─────────── + ─────────── + ───────────
# π        1849⋅π        2025⋅π        2209⋅π        2401⋅π

# %%
# 14
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = integrate(x**2, (x,-pi,pi))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = integrate(x**2*cos(j*x),(x,-pi,pi))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i =  integrate(x**2*sin(j*x),(x,-pi,pi))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(20),(x,-2*pi,2*pi))

# %%
expr1(50)
# Out:
#
#                        4⋅cos(3⋅x)   cos(4⋅x)   4⋅cos(5⋅x)   cos(6⋅x)   4⋅cos(7
# -4⋅cos(x) + cos(2⋅x) - ────────── + ──────── - ────────── + ──────── - ───────
#                            9           4           25          9           49
#
#
# ⋅x)   cos(8⋅x)   4⋅cos(9⋅x)   cos(10⋅x)   4⋅cos(11⋅x)   cos(12⋅x)   4⋅cos(13⋅x
# ─── + ──────── - ────────── + ───────── - ─────────── + ───────── - ──────────
#          16          81           25          121           36          169
#
#
# )   cos(14⋅x)   4⋅cos(15⋅x)   cos(16⋅x)   4⋅cos(17⋅x)   cos(18⋅x)   4⋅cos(19⋅x
# ─ + ───────── - ─────────── + ───────── - ─────────── + ───────── - ──────────
#         49          225           64          289           81          361
#
#
# )   cos(20⋅x)   4⋅cos(21⋅x)   cos(22⋅x)   4⋅cos(23⋅x)   cos(24⋅x)   4⋅cos(25⋅x
# ─ + ───────── - ─────────── + ───────── - ─────────── + ───────── - ──────────
#        100          441          121          529          144          625
#
#
# )   cos(26⋅x)   4⋅cos(27⋅x)   cos(28⋅x)   4⋅cos(29⋅x)   cos(30⋅x)   4⋅cos(31⋅x
# ─ + ───────── - ─────────── + ───────── - ─────────── + ───────── - ──────────
#        169          729          196          841          225          961
#
#
# )   cos(32⋅x)   4⋅cos(33⋅x)   cos(34⋅x)   4⋅cos(35⋅x)   cos(36⋅x)   4⋅cos(37⋅x
# ─ + ───────── - ─────────── + ───────── - ─────────── + ───────── - ──────────
#        256          1089         289          1225         324          1369
#
#
# )   cos(38⋅x)   4⋅cos(39⋅x)   cos(40⋅x)   4⋅cos(41⋅x)   cos(42⋅x)   4⋅cos(43⋅x
# ─ + ───────── - ─────────── + ───────── - ─────────── + ───────── - ──────────
#        361          1521         400          1681         441          1849
#
#
# )   cos(44⋅x)   4⋅cos(45⋅x)   cos(46⋅x)   4⋅cos(47⋅x)   cos(48⋅x)   4⋅cos(49⋅x
# ─ + ───────── - ─────────── + ───────── - ─────────── + ───────── - ──────────
#        484          2025         529          2209         576          2401
#
#      2
# )   π
# ─ + ──
#     3

# %%
# 15
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = (integrate((2*pi+x)**2,(x,-pi,0))
          +integrate(x**2, (x,0,pi)))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = (integrate((2*pi+x)**2*cos(j*x),(x,-pi,0))+
            integrate((x**2)*cos(j*x),(x,0,pi)))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i =  (integrate((2*pi+x)**2*sin(j*x),(x,-pi,0))+
            integrate((x**2)*sin(j*x),(x,0,pi)))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(20),(x,-2*pi,2*pi))

# %%
expr1(20)
# Out:
#
#                              4⋅π⋅sin(3⋅x)                4⋅π⋅sin(5⋅x)   2⋅π⋅si
# -4⋅π⋅sin(x) - 2⋅π⋅sin(2⋅x) - ──────────── - π⋅sin(4⋅x) - ──────────── - ──────
#                                   3                           5              3
#
#
# n(6⋅x)   4⋅π⋅sin(7⋅x)   π⋅sin(8⋅x)   4⋅π⋅sin(9⋅x)   2⋅π⋅sin(10⋅x)   4⋅π⋅sin(11
# ────── - ──────────── - ────────── - ──────────── - ───────────── - ──────────
#               7             2             9               5               11
#
#
# ⋅x)   π⋅sin(12⋅x)   4⋅π⋅sin(13⋅x)   2⋅π⋅sin(14⋅x)   4⋅π⋅sin(15⋅x)   π⋅sin(16⋅x
# ─── - ─────────── - ───────────── - ───────────── - ───────────── - ──────────
#            3              13              7               15             4
#
#
# )   4⋅π⋅sin(17⋅x)   2⋅π⋅sin(18⋅x)   4⋅π⋅sin(19⋅x)                         4⋅co
# ─ - ───────────── - ───────────── - ───────────── + 4⋅cos(x) + cos(2⋅x) + ────
#           17              9               19
#
#
# s(3⋅x)   cos(4⋅x)   4⋅cos(5⋅x)   cos(6⋅x)   4⋅cos(7⋅x)   cos(8⋅x)   4⋅cos(9⋅x)
# ────── + ──────── + ────────── + ──────── + ────────── + ──────── + ──────────
# 9           4           25          9           49          16          81
#
#
#    cos(10⋅x)   4⋅cos(11⋅x)   cos(12⋅x)   4⋅cos(13⋅x)   cos(14⋅x)   4⋅cos(15⋅x)
#  + ───────── + ─────────── + ───────── + ─────────── + ───────── + ───────────
#        25          121           36          169           49          225
#
#                                                           2
#    cos(16⋅x)   4⋅cos(17⋅x)   cos(18⋅x)   4⋅cos(19⋅x)   4⋅π
#  + ───────── + ─────────── + ───────── + ─────────── + ────
#        64          289           81          361        3

# %%
#16
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = integrate(x,(x,-pi/2,pi/2))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = integrate(x*cos(j*x),(x,-pi/2,pi/2))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i = integrate(x*sin(j*x),(x,-pi/2,pi/2))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(40),(x,-2*pi,2*pi))

# %%
expr1(40)
# Out:
# 2⋅sin(x)   sin(2⋅x)   2⋅sin(3⋅x)   sin(4⋅x)   2⋅sin(5⋅x)   sin(6⋅x)   2⋅sin(7⋅
# ──────── + ──────── - ────────── - ──────── + ────────── + ──────── - ────────
#    π          2          9⋅π          4          25⋅π         6          49⋅π
#
# x)   sin(8⋅x)   2⋅sin(9⋅x)   sin(10⋅x)   2⋅sin(11⋅x)   sin(12⋅x)   2⋅sin(13⋅x)
# ── - ──────── + ────────── + ───────── - ─────────── - ───────── + ───────────
#         8          81⋅π          10         121⋅π          12         169⋅π
#
#    sin(14⋅x)   2⋅sin(15⋅x)   sin(16⋅x)   2⋅sin(17⋅x)   sin(18⋅x)   2⋅sin(19⋅x)
#  + ───────── - ─────────── - ───────── + ─────────── + ───────── - ───────────
#        14         225⋅π          16         289⋅π          18         361⋅π
#
#    sin(20⋅x)   2⋅sin(21⋅x)   sin(22⋅x)   2⋅sin(23⋅x)   sin(24⋅x)   2⋅sin(25⋅x)
#  - ───────── + ─────────── + ───────── - ─────────── - ───────── + ───────────
#        20         441⋅π          22         529⋅π          24         625⋅π
#
#    sin(26⋅x)   2⋅sin(27⋅x)   sin(28⋅x)   2⋅sin(29⋅x)   sin(30⋅x)   2⋅sin(31⋅x)
#  + ───────── - ─────────── - ───────── + ─────────── + ───────── - ───────────
#        26         729⋅π          28         841⋅π          30         961⋅π
#
#    sin(32⋅x)   2⋅sin(33⋅x)   sin(34⋅x)   2⋅sin(35⋅x)   sin(36⋅x)   2⋅sin(37⋅x)
#  - ───────── + ─────────── + ───────── - ─────────── - ───────── + ───────────
#        32         1089⋅π         34         1225⋅π         36         1369⋅π
#
#    sin(38⋅x)   2⋅sin(39⋅x)
#  + ───────── - ───────────
#        38         1521⋅π

# %%
#17
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = (integrate(pi+x,(x,-pi,0))
          +integrate(pi-x, (x,0,pi)))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = (integrate((pi+x)*cos(j*x),(x,-pi,0))+
            integrate((pi-x)*cos(j*x),(x,0,pi)))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i =  (integrate((pi+x)*sin(j*x),(x,-pi,0))+
            integrate((pi-x)*sin(j*x),(x,0,pi)))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(20),(x,-2*pi,2*pi))

# %%
expr1(20)
# Out:
# 4⋅cos(x)   4⋅cos(3⋅x)   4⋅cos(5⋅x)   4⋅cos(7⋅x)   4⋅cos(9⋅x)   4⋅cos(11⋅x)   4
# ──────── + ────────── + ────────── + ────────── + ────────── + ─────────── + ─
#    π          9⋅π          25⋅π         49⋅π         81⋅π         121⋅π
#
# ⋅cos(13⋅x)   4⋅cos(15⋅x)   4⋅cos(17⋅x)   4⋅cos(19⋅x)   π
# ────────── + ─────────── + ─────────── + ─────────── + ─
#   169⋅π         225⋅π         289⋅π         361⋅π      2

# %%
# 18
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = integrate(1,(x,0,pi))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = integrate(1*cos(j*x),(x,0,pi))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i = integrate(1*sin(j*x),(x,0,pi))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(20),(x,-2*pi,2*pi))

# %%
expr1(20)
# Out:
# 2⋅sin(x)   2⋅sin(3⋅x)   2⋅sin(5⋅x)   2⋅sin(7⋅x)   2⋅sin(9⋅x)   2⋅sin(11⋅x)   2
# ──────── + ────────── + ────────── + ────────── + ────────── + ─────────── + ─
#    π          3⋅π          5⋅π          7⋅π          9⋅π           11⋅π
#
# ⋅sin(13⋅x)   2⋅sin(15⋅x)   2⋅sin(17⋅x)   2⋅sin(19⋅x)   1
# ────────── + ─────────── + ─────────── + ─────────── + ─
#    13⋅π          15⋅π          17⋅π          19⋅π      2

# %%
# 19
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = integrate(x,(x,0,pi))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = integrate(x*cos(j*x),(x,0,pi))/pi
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i = integrate(x*sin(j*x),(x,0,pi))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(20),(x,-2*pi,2*pi))

# %%
expr1(20)
# Out:
#          sin(2⋅x)   sin(3⋅x)   sin(4⋅x)   sin(5⋅x)   sin(6⋅x)   sin(7⋅x)   sin
# sin(x) - ──────── + ──────── - ──────── + ──────── - ──────── + ──────── - ───
#             2          3          4          5          6          7
#
# (8⋅x)   sin(9⋅x)   sin(10⋅x)   sin(11⋅x)   sin(12⋅x)   sin(13⋅x)   sin(14⋅x)
# ───── + ──────── - ───────── + ───────── - ───────── + ───────── - ───────── +
# 8          9           10          11          12          13          14
#
#  sin(15⋅x)   sin(16⋅x)   sin(17⋅x)   sin(18⋅x)   sin(19⋅x)   2⋅cos(x)   2⋅cos(
#  ───────── - ───────── + ───────── - ───────── + ───────── - ──────── - ──────
#      15          16          17          18          19         π          9⋅π
#
# 3⋅x)   2⋅cos(5⋅x)   2⋅cos(7⋅x)   2⋅cos(9⋅x)   2⋅cos(11⋅x)   2⋅cos(13⋅x)   2⋅co
# ──── - ────────── - ────────── - ────────── - ─────────── - ─────────── - ────
#           25⋅π         49⋅π         81⋅π         121⋅π         169⋅π         2
#
# s(15⋅x)   2⋅cos(17⋅x)   2⋅cos(19⋅x)   π
# ─────── - ─────────── - ─────────── + ─
# 25⋅π         289⋅π         361⋅π      4

# %%
#20
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = (integrate(-pi/2,(x,-pi,-pi/2))
          +integrate(x,(x,-pi/2,pi/2))
         + integrate(pi/2,(x,pi/2,pi)))/(2*pi) 
    expr = a0
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = (integrate(-pi*cos(j*x)/2,(x,-pi,-pi/2))
          +integrate(x*cos(j*x),(x,-pi/2,pi/2))
         + integrate(pi*cos(j*x)/2,(x,pi/2,pi)))/pi 
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i = (integrate(-pi*sin(j*x)/2,(x,-pi,-pi/2))
          +integrate(x*sin(j*x),(x,-pi/2,pi/2))
         + integrate(pi*sin(j*x)/2,(x,pi/2,pi)))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
plot(expr1(40),(x,-2*pi,2*pi))

# %%
#21
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
init_printing(use_unicode= True)

x = symbols('x')

def expr1(k):
    x = symbols('x')
    a0 = (integrate(-pi-x,(x,-pi,0))
          + integrate(pi-x,(x,0,pi)))/(2*pi) 
    expr = a0
    #print(float(a0))
    stra = 'a1:'+ str(k)
    strb = 'b1:'+ str(k)
    syma = symbols(stra)
    symb = symbols(strb)
    j = 1
    for i in syma:
        i = (integrate((-pi-x)*cos(j*x),(x,-pi,0))
          + integrate((pi-x)*cos(j*x),(x,0,pi)))/pi 
        expr += i*cos(j*x)
        j+=1
    j = 1
    for i in symb:
        i = (integrate((-pi-x)*sin(j*x),(x,-pi,0))
          + integrate((pi-x)*sin(j*x),(x,0,pi)))/pi
        expr += i*sin(j*x)
        j+=1
    return expr
#print(expr)
plt.show(plot(expr1(40),(x,-2*pi,2*pi)))
expr1(40)
# Out:
#                       2⋅sin(3⋅x)   sin(4⋅x)   2⋅sin(5⋅x)   sin(6⋅x)   2⋅sin(7⋅
# 2⋅sin(x) + sin(2⋅x) + ────────── + ──────── + ────────── + ──────── + ────────
#                           3           2           5           3           7
#
# x)   sin(8⋅x)   2⋅sin(9⋅x)   sin(10⋅x)   2⋅sin(11⋅x)   sin(12⋅x)   2⋅sin(13⋅x)
# ── + ──────── + ────────── + ───────── + ─────────── + ───────── + ───────────
#         4           9            5            11           6            13
#
#    sin(14⋅x)   2⋅sin(15⋅x)   sin(16⋅x)   2⋅sin(17⋅x)   sin(18⋅x)   2⋅sin(19⋅x)
#  + ───────── + ─────────── + ───────── + ─────────── + ───────── + ───────────
#        7            15           8            17           9            19
#
#    sin(20⋅x)   2⋅sin(21⋅x)   sin(22⋅x)   2⋅sin(23⋅x)   sin(24⋅x)   2⋅sin(25⋅x)
#  + ───────── + ─────────── + ───────── + ─────────── + ───────── + ───────────
#        10           21           11           23           12           25
#
#    sin(26⋅x)   2⋅sin(27⋅x)   sin(28⋅x)   2⋅sin(29⋅x)   sin(30⋅x)   2⋅sin(31⋅x)
#  + ───────── + ─────────── + ───────── + ─────────── + ───────── + ───────────
#        13           27           14           29           15           31
#
#    sin(32⋅x)   2⋅sin(33⋅x)   sin(34⋅x)   2⋅sin(35⋅x)   sin(36⋅x)   2⋅sin(37⋅x)
#  + ───────── + ─────────── + ───────── + ─────────── + ───────── + ───────────
#        16           33           17           35           18           37
#
#    sin(38⋅x)   2⋅sin(39⋅x)
#  + ───────── + ───────────
#        19           39

# %%
#22.a
x = symbols('x')
expr = 0
for i in range(1,20):
    if i%2 == 0:
        expr += -sin(i*x)
    else:
        expr += sin(i*x)
expr *= 2
plt.show(plot(expr,(x,-4*pi,4*pi)))

# %%
#22.b
x = symbols('x')
expr = 0
for i in range(1,20,2):
    expr += cos(i*x)/i**2
expr *= 4/pi**2
expr += 0.5
plt.show(plot(expr,(x,-2*pi,2*pi)))

# %%
#22.c
x = symbols('x')
expr = 0
for i in range(1,20):
    expr += (-1**(i+1))*cos(i*x)/i**2
expr *= 4
expr += 2*(pi**2)/3
plt.show(plot(expr,(x,-2*pi,2*pi)))
